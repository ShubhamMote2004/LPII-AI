# %%
knowledge_base = {"shirdi sai baba temple": 
{
"description": "The Shirdi Sai Baba Temple is a sacred pilgrimage site dedicated to the revered saint Sai Baba. It attracts millions of devotees from all over the world seeking blessings and spiritual solace.",
"Location": "Located in the small town of Shirdi in the Ahmednagar district of Maharashtra, India.",
"How To visit": "Devotees can reach Shirdi by train, bus, or car. The nearest railway station is Sainagar Shirdi Railway Station, which is well-connected to major cities like Mumbai and Pune.",
"Best Time To Visit": "The best time to visit the Shirdi Sai Baba Temple is during festivals like Ram Navami and Guru Purnima when the town is adorned with lights and celebrations."
},

"ajanta caves": 
{
"description": "The Ajanta Caves are a UNESCO World Heritage Site known for their exquisite rock-cut Buddhist cave monuments. These caves showcase remarkable sculptures, paintings, and architecture dating back to the 2nd century BCE to 480 CE.",
"Location": "Situated in the Aurangabad district of Maharashtra, approximately 100 kilometers from Aurangabad city.",
"How To visit": "Visitors can reach the Ajanta Caves by road from Aurangabad. There are also guided tours available from Aurangabad that include transportation to the caves.",
"Best Time To Visit": "The best time to visit the Ajanta Caves is during the winter months, from November to February, when the weather is pleasant and conducive for exploring the site."
},

"elephanta caves": 
{
"description": "The Elephanta Caves are a collection of rock-cut cave temples dedicated to the Hindu god Shiva. These caves are renowned for their intricate sculptures, especially the colossal statue of Trimurti, depicting Shiva in three forms: creator, preserver, and destroyer.",
"Location": "Located on Elephanta Island in the Mumbai Harbour, about 10 kilometers east of Mumbai's mainland.",
"How To visit": "Tourists can reach Elephanta Island by taking a ferry from the Gateway of India in Mumbai. The ferry ride offers beautiful views of the city skyline and the Arabian Sea.",
"Best Time To Visit": "The best time to visit the Elephanta Caves is during the winter months, from November to February, to avoid the heat and humidity of Mumbai's summer."
},

"matheran": 
{
"description": "Matheran is a serene hill station nestled in the Western Ghats of Maharashtra. Known for its lush greenery, breathtaking viewpoints, and toy train ride, Matheran offers a peaceful retreat away from the hustle and bustle of city life.",
"Location": "Situated in the Raigad district of Maharashtra, approximately 90 kilometers from Mumbai.",
"How To visit": "Visitors can reach Matheran by train, as the nearest railway station is Neral Junction. From Neral, one can take a toy train or hire a taxi to reach Matheran.",
"Best Time To Visit": "The best time to visit Matheran is during the monsoon season, from June to September, when the hills are covered in lush greenery and the waterfalls are at their peak."
},

"pune": 
{
"description": "Pune, also known as the 'Oxford of the East', is a vibrant city in Maharashtra known for its rich history, culture, and educational institutions. It is home to several historical landmarks, bustling markets, and delectable cuisine.",
"Location": "Located in the western Indian state of Maharashtra, approximately 150 kilometers southeast of Mumbai.",
"How To visit": "Pune is well-connected by road, rail, and air. The city has its own airport, Pune International Airport, which connects it to major cities across India. It is also accessible by train and bus from Mumbai and other neighboring cities.",
"Best Time To Visit": "The best time to visit Pune is during the winter months, from October to March, when the weather is pleasant and conducive for outdoor activities and sightseeing."
}

                 }

# %%
def respond(identified_words):
    for i in identified_words:
        print("Here is the Brief Information about ", i, "\n")
        print("-------- DESCRIPTION -------- \n", knowledge_base[i]["description"])
        print("--------  LOCATION  -------- \n", knowledge_base[i]["Location"])
        print("-------- How To visit -------- \n", knowledge_base[i]["How To visit"])
        print("-------- Best Time To Visit -------- \n", knowledge_base[i]["Best Time To Visit"])
        print("____________________________________________________________\n\n")
        
    

def solve_query(query):
    required = list(query.split())
    knowledge = list(knowledge_base.keys())
    identified_words = []
    for i in range(len(required)):
        for j in range(len(knowledge)):
            if required[i] == knowledge[j]:
                identified_words.append(required[i])
    
    respond(identified_words)
    

def get_query():
    print("How may I help you?\n")
    asked_query = input("Enter Here: ")
    query = asked_query.lower()
    if query == "exit" or query == "quit":
        print("Thank You :) ")
    else:
        solve_query(query)
        

get_query()
# Out:
# How may I help you?
#
# Enter Here: tell me something about Pune and Where to go MaThERan
# Here is the Brief Information about  pune
#
# -------- DESCRIPTION --------
#  Pune, also known as the 'Oxford of the East', is a vibrant city in Maharashtra known for its rich history, culture, and educational institutions. It is home to several historical landmarks, bustling markets, and delectable cuisine.
# --------  LOCATION  --------
#  Located in the western Indian state of Maharashtra, approximately 150 kilometers southeast of Mumbai.
# -------- How To visit --------
#  Pune is well-connected by road, rail, and air. The city has its own airport, Pune International Airport, which connects it to major cities across India. It is also accessible by train and bus from Mumbai and other neighboring cities.
# -------- Best Time To Visit --------
# ...
